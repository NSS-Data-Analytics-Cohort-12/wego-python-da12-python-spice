# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
wego = pd.read_csv("../data/Headway Data, 8-1-2023 to 9-30-2023.csv")

wego.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120230801             1      99457890  2023-08-01          22
# 1    120230801             1      99457891  2023-08-01          22
# 2    120230801             1      99457892  2023-08-01          22
# 3    120230801             1      99457893  2023-08-01          22
# 4    120230801             1      99457894  2023-08-01          22
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# 0        2200      1040   345104            0          TO DOWNTOWN  ...
# 1        2200      1040   345104            0          TO DOWNTOWN  ...
# 2        2200      1040   345104            0          TO DOWNTOWN  ...
# 3        2200      1040   345104            0          TO DOWNTOWN  ...
# 4        2200      1040   345105            0        FROM DOWNTOWN  ...
#
#   ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# ...

# %%
wego.columns
# Out:
# Index(['CALENDAR_ID', 'SERVICE_ABBR', 'ADHERENCE_ID', 'DATE', 'ROUTE_ABBR',
#        'BLOCK_ABBR', 'OPERATOR', 'TRIP_ID', 'OVERLOAD_ID',
#        'ROUTE_DIRECTION_NAME', 'TIME_POINT_ABBR', 'ROUTE_STOP_SEQUENCE',
#        'TRIP_EDGE', 'LATITUDE', 'LONGITUDE', 'SCHEDULED_TIME',
#        'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE',
#        'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
#        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'STOP_CANCELLED',
#        'PREV_SCHED_STOP_CANCELLED', 'IS_RELIEF', 'DWELL_IN_MINS',
#        'SCHEDULED_LAYOVER_MINUTES'],
#       dtype='object')

# %% [markdown]
# ### 1. What is the overall on-time performance, and what do the overall distributions of adherence and headway deviation look like?

# %%
wego[['DATE','ACTUAL_HDWY','SCHEDULED_HDWY','ADHERENCE','ADJUSTED_ONTIME_COUNT']]
# Out:
#               DATE  ACTUAL_HDWY  SCHEDULED_HDWY  ADHERENCE  \
# 0       2023-08-01          NaN             NaN  -2.133333
# 1       2023-08-01          NaN             NaN  -2.450000
# 2       2023-08-01          NaN             NaN  -0.933333
# 3       2023-08-01          NaN             NaN   6.283333
# 4       2023-08-01          NaN             NaN  -1.583333
# ...            ...          ...             ...        ...
# 350324  2023-09-30    35.266666            30.0  -8.433333
# 350325  2023-09-30          NaN             NaN -11.300000
# 350326  2023-09-30    31.866666            30.0  -4.316666
# 350327  2023-09-30    47.500000            30.0 -22.083333
# 350328  2023-09-30          NaN             NaN -23.666666
#
#         ADJUSTED_ONTIME_COUNT
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# 350324                      0
# ...

# %%
wego['hdwy_dev'] = wego['ACTUAL_HDWY'] - wego['SCHEDULED_HDWY']
wego
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0         120230801             1      99457890  2023-08-01          22
# 1         120230801             1      99457891  2023-08-01          22
# 2         120230801             1      99457892  2023-08-01          22
# 3         120230801             1      99457893  2023-08-01          22
# 4         120230801             1      99457894  2023-08-01          22
# ...             ...           ...           ...         ...         ...
# 350324    120230930             2     100406610  2023-09-30           7
# 350325    120230930             2     100406611  2023-09-30           7
# 350326    120230930             2     100406612  2023-09-30           7
# 350327    120230930             2     100406613  2023-09-30           7
# 350328    120230930             2     100406614  2023-09-30           7
#
#         BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
wego_avg_ontime = f"{sum(wego['ADJUSTED_ONTIME_COUNT'])/len(wego):.0%}"
wego_avg_ontime
# Out:
# '77%'

# %%
plt.hist(wego['ADHERENCE'],bins = range(-40,40))
plt.show()

# %%
sns.histplot(wego['ADHERENCE'], bins=range(-40, 40), kde=False,color='purple', edgecolor='gray')
plt.show()
# Out:
# C:\Users\Bamaf\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.hist(wego['hdwy_dev'],bins = range(-40,40))
plt.show()

# %%
sns.histplot(wego['hdwy_dev'], bins=range(-40, 40), kde=False,color='purple', edgecolor='gray')
plt.show()
# Out:
# C:\Users\Bamaf\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
wego[['TRIP_EDGE']] =1

print (wego[['TRIP_EDGE']])
# Out:
#         TRIP_EDGE
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 350324          1
# 350325          1
# 350326          1
# 350327          1
# 350328          1
#
# [350329 rows x 1 columns]

# %%
len(wego['TRIP_EDGE'] == 1)
# Out:
# 350329
